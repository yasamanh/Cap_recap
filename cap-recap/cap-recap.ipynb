# %%
def capture_recapture(m_f, c_s, m_s):
    N = float(m_f)*float(c_s)/float(m_s)
    print N

# %%
capture_recapture(5,4,1)
# Out:
# 20.0

# %%
f = open('/Users/ynh3/Documents/estR/trace.2q50docs','rb')
next(f)
next(f)
for row in f:
    line = row.strip()    
    line = line.partition(' ')[2]
    text = line.split(' ')[3]
    text2 = line.split(' ')[4]
    print text, text2
# Out:
# 50 27
# 68 39
# 50 13
# 94 56
# 50 26
# 94 55
# 50 37
# 100 40
# 50 46
# 85 74
# 50 34
# 78 55
# 50 34
# 88 52
# 50 32
# 74 55
# 50 4
# 83 4
# 50 4
# 94 4
# 50 16
# 88 51
# 50 26
# 72 37
# 50 14
# 77 16
# 50 17
# 82 26
# 50 30
# 61 35
# 50 28
# 83 43
# 50 1
# 100 1
# 50 30
# 100 34
# 50 8
# 82 12
# 50 12
# 87 14
# 50 2
# 100 38
# 50 3
# 100 3
# 50 21
# 100 22
# 50 0
# 97 0
# 50 1
# 98 7
# 50 7
# 88 24
# 50 34
# 68 44
# 50 40
# 64 50
# 50 15
# 98 23
# 50 9
# 100 9
# 50 4
# 91 5
# 50 45
# 98 49
# 50 4
# 100 5
# 50 7
# 78 7
# 50 7
# 99 27
# 50 7
# 92 37
# 50 10
# 87 10
# 50 19
# 99 19
# 50 8
# 91 9
# 50 32
# 99 36
# 50 5
# 100 5
# 50 4
# 100 5
# 50 22
# 58 22
# 50 16
# 62 19
# 50 11
# 74 14
# 50 13
# 97 28
# 50 6
# 87 8
# 50 20
# 82 24
# 50 24
# 95 36
# 50 21
# 95 53
# 50 27
# 69 38
# 50 2
# 100 49
# 50 10
# 99 46
# 50 37
# 84 51
# 50 47
# 84 78
# 50 48
# 71 65
# 50 41
# 89 62
# 50 45
# 66 59
# 50 9
# 88 9
# 50 1
# 93 1
# 50 4
# 100 4
# 50 20
# 77 37
# 50 27
# 63 30
# 50 23
# 94 27
# ...

# %%
data = list(csv.reader(open('/Users/ynh3/Documents/estR/trace.2q50docs', 'rb'), delimiter='\t'))

# %%
data[3]
# Out:
# ['IN7a 51 1  68 39 38 12 6']

# %%
f = open ( '/Users/ynh3/Documents/estR/trace.2q50docs' , 'r')
next(f)
next(f)
l = [ map(int,line.split(',')) for line in f ]
print l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-3bba9ad8f323> in <module>()
#       2 next(f)
#       3 next(f)
# ----> 4 l = [ map(int,line.split(',')) for line in f ]
#       5 print l
#
# ValueError: invalid literal for int() with base 10: 'IN7a 51 0  50 27 27 27 23\n'

# %%
for x in data[4]:
    print x
# Out:
# IN7a 51 1  68 39 38 12 6

# %%
a = [x[2] for x in data[3]]
print a
# Out:
# ['7']

# %%
import csv
rel_found=[]

with open('/Users/ynh3/Documents/estR/trace.2q50docs','rb') as f:
    next(f) 
    next(f)
    reader=csv.reader(f,delimiter='\t')
    #for system,topic,query,rel_found,marked,a,b,c in reader:
    for row in reader:
        #d = list(row)
        #d = row.split()
        #print row[0]
        
#print(rel_found)
# Out:
#   File "<ipython-input-64-24063684717f>", line 7
#     reader=csv.reader(f,delimiter='\t)
#                                      ^
# SyntaxError: EOL while scanning string literal

# %%
name = "word1 word2 word3"
print name.split(" ")[0]
# Out:
# word1

# %%
import csv
with open('/Users/ynh3/Documents/estR/trec_test.txt', 'rb') as f:
    reader = csv.reader(f, dialect='excel', delimiter='\t')
    for row in reader:
        print row
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-8-c81e81f57a28> in <module>()
#       2 with open('/Users/ynh3/Documents/estR/trec_test.txt', 'rb') as f:
#       3     reader = csv.reader(f, dialect='excel', delimiter='\t')
# ----> 4     for row in reader:
#       5         print row
#
# Error: new-line character seen in unquoted field - do you need to open the file in universal-newline mode?

# %%
path = '/Users/ynh3/Documents/estR/trec_test.txt'
import numpy as np
d = np.load(path, delimiter="\t")
print d[0,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d7e7c6c4049f> in <module>()
#       1 path = '/Users/ynh3/Documents/estR/trec_test.txt'
#       2 import numpy as np
# ----> 3 d = np.load(path, delimiter="\t")
#       4 print d[0,2]
#
# TypeError: load() got an unexpected keyword argument 'delimiter'

# %%
lol = list(csv.reader(open('/Users/ynh3/Documents/estR/trec_test.txt', 'rb'), delimiter='\t'))
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-14-ce25222a0104> in <module>()
# ----> 1 lol = list(csv.reader(open('/Users/ynh3/Documents/estR/trec_test.txt', 'rb'), delimiter='\t'))
#
# Error: new-line character seen in unquoted field - do you need to open the file in universal-newline mode?
