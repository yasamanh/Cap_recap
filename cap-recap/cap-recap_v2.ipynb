# %%
import numpy

# %%
def truncate(f, n):
    '''Truncates/pads a float f to n decimal places without rounding'''
    s = '{}'.format(f)
    if 'e' in s or 'E' in s:
        return '{0:.{1}f}'.format(f, n)
    i, p, d = s.partition('.')
    return '.'.join([i, (d+'0'*n)[:n]])

# %%
def capture_recapture(m_f, c_s, m_s):
    if float(m_s)== 0.0: return 0
    else:
        N = float(m_f)*float(c_s)/float(m_s)
        return float(truncate(N,0))

# %%
capture_recapture(10,15,5)
# Out:
# 30.0

# %%
def capture_recapture_chapman(m_f, c_s, m_s):
    N = (float(m_f)+1)*(float(c_s)+1)/(float(m_s)+1) - 1
    #print "EstR: ",float(truncate(N,0))
    return float(truncate(N,0))

# %%
capture_recapture_chapman(10,15,5)
# Out:
# 28.0

# %%
#def capture_recapture_Schnabel_index(n_iterations, total_num_prev_marked, num_cought_iter_i, num_marked_prev_iter_i)
def capture_recapture_schnabel_index_iteration(num_itr, prev_marked, num_captured, marked_caught):
    a = 0
    b = 0
    for i in range(0,num_itr):
        a += float(prev_marked[i])*float(num_captured[i])
        
    for j in range(0,num_itr):
        b += float(marked_caught[j])
         
    if b== 0.0: return 0
    else:
        N = float(a/b)
        #return float(truncate(N,0))
        return N

# %%
prev_marked=[0,100,170]
num_captured=[100,85,105]
marked_caught=[0,15,25]
n=3
print capture_recapture_schnabel_index_iteration(n, prev_marked, num_captured, marked_caught)
# Out:
# 658.75

# %%
prev_marked=[0,27,39]
num_captured=[27,38,39]
marked_caught=[0,26,38]
n=3
print capture_recapture_schnabel_index_iteration(n, prev_marked, num_captured, marked_caught)
# Out:
# 39.796875

# %%
prev_marked=[0,24,35]
num_captured=[24,35,34]
marked_caught=[0,24,34]
n=3
print capture_recapture_schnabel_index_iteration(n, prev_marked, num_captured, marked_caught)
# Out:
# 35.0

# %%
capture_recapture_schnabel_index_iteration

# %%
#def capture_recapture_Schnabel_index(n_iterations, total_num_prev_marked, num_cought_iter_i, num_marked_prev_iter_i)
def capture_recapture_schnabel_index(m_f, c_s, remark_s, c_3rd, remarked_3rd):
    soorat = float(m_f)*float(c_s) + (float(m_f)+float(c_s)-float(remark_s))*float(c_3rd) 
    denum = float(remark_s)+ float(remarked_3rd)
    N = float(soorat/denum)
    return float(truncate(N,0))

# %%
capture_recapture_schnabel_index(100,85,15,105,25)
# Out:
# 658.0

# %%
def AER(N,Actual_N):
    aer = float(abs(N - Actual_N))/Actual_N
    return float(truncate(aer,2))

# %%
AER(20,30)
# Out:
# 0.33

# %%
f2 = open('/Users/ynh3/Documents/estR/rel_counts','rb')
rel_judged = []
for row in f2:
    words = row.split()  
    rel_judged.append(words[3])
print rel_judged
# Out:
# ['75', '284', '367', '106', '578', '619', '280', '108', '339', '45', '154', '167', '166', '171', '285', '151', '364', '148', '33', '18', '190', '61', '135', '275', '252', '168', '75', '74', '176', '211', '29', '360', '453', '316', '581', '139', '90', '86', '113', '166', '22', '44', '105', '174', '164', '582', '205', '363', '189', '211']

# %%
f = open('/Users/ynh3/Documents/estR/trace.2q50docs','rb')
next(f)
next(f)
count = 0
AER_arr=[]

#print header
print "system, topic num, estR, relevant_judged, AER(estR, rel_judged[count]))"

for row in f:
    line = row.strip() 
    system = line.partition(' ')[0]
    line = line.partition(' ')[2]
    total_rel_first_round = line.split(' ')[5]
    new_rel_first_round = line.split(' ')[6]
    #print total_rel_first_round, new_rel_first_round
    row = next(f)
    line = row.strip()    
    line = line.partition(' ')[2]
    total_rel_second_round = line.split(' ')[5]
    new_rel_second_round = line.split(' ')[6]
    rel_overlap = float(total_rel_second_round) - float(new_rel_second_round)
    N = capture_recapture_chapman(total_rel_first_round, total_rel_second_round, rel_overlap)
    AER_arr.append(AER(N,float(rel_judged[count]))) 
    print system, count, N, rel_judged[count], AER(N,float(rel_judged[count]))
    #AER(N,float(rel_judged[count]))
    count = count +1
    if count > 49: 
        print "Mean of AER System ", system, ":", numpy.mean(AER_arr)
        count = 0
        AER_arr =[]
# Out:
# system, topic num, estR, relevant_judged, AER(estR, rel_judged[count]))
# IN7a 0 39.0 75 0.48
# IN7a 1 99.0 284 0.65
# IN7a 2 182.0 367 0.5
# IN7a 3 151.0 106 0.42
# IN7a 4 128.0 578 0.77
# IN7a 5 65.0 619 0.89
# IN7a 6 104.0 280 0.62
# IN7a 7 60.0 108 0.44
# IN7a 8 4.0 339 0.98
# IN7a 9 4.0 45 0.91
# IN7a 10 61.0 154 0.6
# IN7a 11 44.0 167 0.73
# IN7a 12 16.0 166 0.9
# IN7a 13 37.0 171 0.78
# IN7a 14 35.0 285 0.87
# IN7a 15 53.0 151 0.64
# IN7a 16 1.0 364 0.99
# IN7a 17 154.0 148 0.04
# IN7a 18 12.0 33 0.63
# IN7a 19 14.0 18 0.22
# IN7a 20 110.0 190 0.42
# IN7a 21 3.0 61 0.95
# IN7a 22 43.0 135 0.68
# IN7a 23 0.0 275 1.0
# IN7a 24 13.0 252 0.94
# IN7a 25 24.0 168 0.85
# IN7a 26 48.0 75 0.36
# IN7a 27 52.0 74 0.29
# IN7a 28 79.0 176 0.55
# IN7a 29 9.0 211 0.95
# IN7a 30 5.0 29 0.82
# IN7a 31 106.0 360 0.7
# IN7a 32 9.0 453 0.98
# IN7a 33 7.0 316 0.97
# IN7a 34 167.0 581 0.71
# IN7a 35 87.0 139 0.37
# IN7a 36 10.0 90 0.88
# IN7a 37 19.0 86 0.77
# IN7a 38 9.0 113 0.92
# IN7a 39 164.0 166 0.01
# IN7a 40 5.0 22 0.77
# IN7a 41 9.0 44 0.79
# IN7a 42 22.0 105 0.79
# IN7a 43 19.0 174 0.89
# IN7a 44 17.0 164 0.89
# IN7a 45 83.0 582 0.85
# IN7a 46 13.0 205 0.93
# IN7a 47 32.0 363 0.91
# IN7a 48 99.0 189 0.47
# IN7a 49 161.0 211 0.23
# Mean of AER System  IN7a : 0.694
# IN7e 0 38.0 75 0.49
# IN7e 1 143.0 284 0.49
# IN7e 2 208.0 367 0.43
# IN7e 3 72.0 106 0.32
# IN7e 4 134.0 578 0.76
# IN7e 5 75.0 619 0.87
# IN7e 6 114.0 280 0.59
# Sabe 14 30.0 285 0.89
# Sabe 15 50.0 151 0.66
# Sabe 16 1.0 364 0.99
# Sabe 17 124.0 148 0.16
# Sabe 18 13.0 33 0.6
# Sabe 19 17.0 18 0.05
# Sabe 20 79.0 190 0.58
# Sabe 21 6.0 61 0.9
# Sabe 22 71.0 135 0.47
# Sabe 23 2.0 275 0.99
# Sabe 24 11.0 252 0.95
# Sabe 25 33.0 168 0.8
# Sabe 26 41.0 75 0.45
# Sabe 27 45.0 74 0.39
# Sabe 28 49.0 176 0.72
# Sabe 29 139.0 211 0.34
# Sabe 30 11.0 29 0.62
# Sabe 31 287.0 360 0.2
# Sabe 32 71.0 453 0.84
# Sabe 33 3.0 316 0.99
# Sabe 34 191.0 581 0.67
# Sabe 35 42.0 139 0.69
# Sabe 36 3.0 90 0.96
# Sabe 37 11.0 86 0.87
# Sabe 38 11.0 113 0.9
# Sabe 39 135.0 166 0.18
# Sabe 40 5.0 22 0.77
# Sabe 41 8.0 44 0.81
# Sabe 42 46.0 105 0.56
# Sabe 43 21.0 174 0.87
# Sabe 44 11.0 164 0.93
# Sabe 45 22.0 582 0.96
# Sabe 46 12.0 205 0.94
# Sabe 47 22.0 363 0.93
# Sabe 48 49.0 189 0.74
# Sabe 49 75.0 211 0.64
# Mean of AER System  Sabe : 0.6656
# Sabm 0 28.0 75 0.62
# Sabm 1 244.0 284 0.14
# Sabm 2 239.0 367 0.34
# Sabm 3 203.0 106 0.91
# Sabm 4 120.0 578 0.79
# Sabm 5 82.0 619 0.86
# Sabm 6 56.0 280 0.8
# Sabm 7 52.0 108 0.51
# Sabm 8 5.0 339 0.98
# Sabm 9 9.0 45 0.8
# Sabm 10 51.0 154 0.66
# Sabm 11 45.0 167 0.73
# Sabm 12 31.0 166 0.81
# Sabm 13 33.0 171 0.8
# Sabm 14 24.0 285 0.91
# Sabm 15 53.0 151 0.64
# Sabm 16 1.0 364 0.99
# Sabm 17 124.0 148 0.16
# Sabm 18 16.0 33 0.51
# Sabm 19 15.0 18 0.16
# Sabm 20 61.0 190 0.67
# Sabm 21 5.0 61 0.91
# Sabm 22 49.0 135 0.63
# Sabm 23 1.0 275 0.99
# Sabm 24 34.0 252 0.86
# Sabm 25 36.0 168 0.78
# Sabm 26 33.0 75 0.56
# Sabm 27 46.0 74 0.37
# Sabm 28 72.0 176 0.59
# Sabm 29 64.0 211 0.69
# Sabm 30 9.0 29 0.68
# Sabm 31 149.0 360 0.58
# Sabm 32 19.0 453 0.95
# Sabm 33 2.0 316 0.99
# Sabm 34 269.0 581 0.53
# Sabm 35 50.0 139 0.64
# Sabm 36 5.0 90 0.94
# Sabm 37 14.0 86 0.83
# Sabm 38 10.0 113 0.91
# Sabm 39 184.0 166 0.1
# Sabm 40 8.0 22 0.63
# Sabm 41 6.0 44 0.86
# Sabm 42 39.0 105 0.62
# Sabm 43 24.0 174 0.86
# Sabm 44 11.0 164 0.93
# Sabm 45 22.0 582 0.96
# Sabm 46 10.0 205 0.95
# Sabm 47 25.0 363 0.93
# Sabm 48 49.0 189 0.74
# UoMl 32 62.0 453 0.86
# UoMl 33 2.0 316 0.99
# UoMl 34 95.0 581 0.83
# UoMl 35 45.0 139 0.67
# UoMl 36 5.0 90 0.94
# UoMl 37 2.0 86 0.97
# UoMl 38 6.0 113 0.94
# UoMl 39 57.0 166 0.65
# UoMl 40 2.0 22 0.9
# UoMl 41 5.0 44 0.88
# UoMl 42 1.0 105 0.99
# UoMl 43 20.0 174 0.88
# UoMl 44 7.0 164 0.95
# UoMl 45 22.0 582 0.96
# UoMl 46 11.0 205 0.94
# UoMl 47 28.0 363 0.92
# UoMl 48 42.0 189 0.77
# UoMl 49 155.0 211 0.26
# Mean of AER System  UoMl : 0.7646
# hum4 0 41.0 75 0.45
# hum4 1 127.0 284 0.55
# hum4 2 139.0 367 0.62
# hum4 3 73.0 106 0.31
# hum4 4 179.0 578 0.69
# hum4 5 91.0 619 0.85
# hum4 6 220.0 280 0.21
# hum4 7 71.0 108 0.34
# hum4 8 65.0 339 0.8
# hum4 9 2.0 45 0.95
# hum4 10 29.0 154 0.81
# hum4 11 12.0 167
# 0.92
# hum4 12 19.0 166 0.88
# hum4 13 3.0 171 0.98
# hum4 14 32.0 285 0.88
# hum4 15 155.0 151 0.02
# hum4 16 1.0 364 0.99
# hum4 17 71.0 148 0.52
# hum4 18 13.0 33 0.6
# hum4 19 16.0 18 0.11
# hum4 20 101.0 190 0.46
# hum4 21 1.0 61 0.98
# hum4 22 45.0 135 0.66
# hum4 23 2.0 275 0.99
# hum4 24 6.0 252 0.97
# hum4 25 34.0 168 0.79
# hum4 26 30.0 75 0.6
# hum4 27 53.0 74 0.28
# hum4 28 125.0 176 0.28
# hum4 29 59.0 211 0.72
# hum4 30 6.0 29 0.79
# hum4 31 101.0 360 0.71
# hum4 32 89.0 453 0.8
# hum4 33 9.0 316 0.97
# hum4 34 170.0 581 0.7
# hum4 35 76.0 139 0.45
# hum4 36 17.0 90 0.81
# hum4 37 23.0 86 0.73
# hum4 38 19.0 113 0.83
# hum4 39 92.0 166 0.44
# hum4 40 3.0 22 0.86
# hum4 41 4.0 44 0.9
# hum4 42 30.0 105 0.71
# hum4 43 22.0 174 0.87
# hum4 44 11.0 164 0.93
# hum4 45 26.0 582 0.95
# hum4 46 17.0 205 0.91
# hum4 47 91.0 363 0.74
# hum4 48 4.0 189 0.97
# hum4 49 192.0 211 0.09
# Mean of AER System  hum4 : 0.6874
# humA 0 41.0 75 0.45
# humA 1 127.0 284 0.55
# humA 2 24.0 367 0.93
# humA 3 73.0 106 0.31
# humA 4 195.0 578 0.66
# humA 5 91.0 619 0.85
# humA 6 182.0 280 0.35
# humA 7 71.0 108 0.34
# humA 8 65.0 339 0.8
# humA 9 2.0 45 0.95
# humA 10 68.0 154 0.55
# humA 11 12.0 167 0.92
# humA 12 17.0 166 0.89
# humA 13 69.0 171 0.59
# humA 14 32.0 285 0.88
# humA 15 137.0 151 0.09
# humA 16 1.0 364 0.99
# humA 17 71.0 148 0.52
# humA 18 16.0 33 0.51
# humA 19 16.0 18 0.11
# humA 20 142.0 190 0.25
# humA 21 7.0 61 0.88
# humA 22 45.0 135 0.66
# humA 23 3.0 275 0.98
# humA 24 4.0 252 0.98
# humA 25 32.0 168 0.8
# humA 26 30.0 75 0.6
# humA 27 49.0 74 0.33
# humA 28 125.0 176 0.28
# humA 29 59.0 211 0.72
# humA 30 4.0 29 0.86
# humA 31 101.0 360 0.71
# humA 32 89.0 453 0.8
# humA 33 9.0 316 0.97
# humA 34 170.0 581 0.7
# humA 35 76.0 139 0.45
# humA 36 17.0 90 0.81
# humA 37 24.0 86 0.72
# humA 38 12.0 113 0.89
# humA 39 92.0 166 0.44
# humA 40 3.0 22 0.86
# humA 41 4.0 44 0.9
# humA 42 30.0 105 0.71
# humA 43 18.0 174 0.89
# humA 44 9.0 164 0.94
# humA 45 26.0 582 0.95
# humA 46 21.0 205 0.89
# humA 47 211.0 363 0.41
# humA 48 151.0 189 0.2
# humA 49 149.0 211 0.29
# Mean of AER System  humA : 0.6622
# humB 0 41.0 75 0.45
# humB 1 127.0 284 0.55
# humB 2 24.0 367 0.93
# humB 3 73.0 106 0.31
# humB 4 195.0 578 0.66
# humB 5 91.0 619 0.85
# humB 6 182.0 280 0.35
# humB 7 71.0 108 0.34
# humB 8 65.0 339 0.8
# humB 9 2.0 45 0.95
# humB 10 68.0 154 0.55
# humB 11 12.0 167 0.92
# humB 12 17.0 166 0.89
# humB 13 74.0 171 0.56
# humB 14 32.0 285 0.88
# humB 15 137.0 151 0.09
# humB 16 1.0 364 0.99
# humB 17 71.0 148 0.52
# humB 18 16.0 33 0.51
# humB 19 16.0 18 0.11
# humB 20 142.0 190 0.25
# humB 21 7.0 61 0.88
# humB 22 45.0 135 0.66
# humB 23 3.0 275 0.98
# humB 24 4.0 252 0.98
# humB 25 32.0 168 0.8
# humB 26 30.0 75 0.6
# humB 27 49.0 74 0.33
# humB 28 125.0 176 0.28
# humB 29 59.0 211 0.72
# humB 30 4.0 29 0.86
# humB 31 101.0 360 0.71
# humB 32 89.0 453 0.8
# humB 33 9.0 316 0.97
# humB 34 170.0 581 0.7
# humB 35 76.0 139 0.45
# humB 36 17.0 90 0.81
# humB 37 24.0 86 0.72
# humB 38 12.0 113 0.89
# humB 39 92.0 166 0.44
# humB 40 3.0 22 0.86
# humB 41 4.0 44 0.9
# humB 42 30.0 105 0.71
# humB 43 18.0 174 0.89
# humB 44 9.0 164 0.94
# humB 45 26.0 582 0.95
# humB 46 21.0 205 0.89
# humB 47 211.0 363 0.41
# humB 48 151.0 189 0.2
# humB 49 149.0 211 0.29
# Mean of AER System  humB : 0.6616
# humD 0 46.0 75 0.38
# humD 1 157.0 284 0.44
# humD 2 29.0 367 0.92
# humD 3 67.0 106 0.36
# humD 4 126.0 578 0.78
# humD 5 87.0 619 0.85
# humD 6 135.0 280 0.51
# humD 7 62.0 108 0.42
# humD 8 79.0 339 0.76
# humD 9 4.0 45 0.91
# humD 10 63.0 154 0.59
# humD 11 14.0 167 0.91
# humD 12 20.0 166 0.87
# humD 13 65.0 171 0.61
# humD 14 32.0 285 0.88
# humK 9 2.0 45 0.95
# humK 10 73.0 154 0.52
# humK 11 12.0 167 0.92
# humK 12 17.0 166 0.89
# humK 13 74.0 171 0.56
# humK 14 35.0 285 0.87
# humK 15 107.0 151 0.29
# humK 16 1.0 364 0.99
# humK 17 71.0 148 0.52
# humK 18 16.0 33 0.51
# humK 19 16.0 18 0.11
# humK 20 142.0 190 0.25
# humK 21 5.0 61 0.91
# humK 22 45.0 135 0.66
# humK 23 3.0 275 0.98
# humK 24 6.0 252 0.97
# humK 25 32.0 168 0.8
# humK 26 30.0 75 0.6
# humK 27 49.0 74 0.33
# humK 28 125.0 176 0.28
# humK 29 59.0 211 0.72
# humK 30 4.0 29 0.86
# humK 31 101.0 360 0.71
# humK 32 89.0 453 0.8
# humK 33 9.0 316 0.97
# humK 34 170.0 581 0.7
# humK 35 76.0 139 0.45
# humK 36 17.0 90 0.81
# humK 37 24.0 86 0.72
# humK 38 12.0 113 0.89
# humK 39 92.0 166 0.44
# humK 40 3.0 22 0.86
# humK 41 4.0 44 0.9
# humK 42 30.0 105 0.71
# humK 43 19.0 174 0.89
# humK 44 11.0 164 0.93
# humK 45 18.0 582 0.96
# humK 46 26.0 205 0.87
# humK 47 503.0 363 0.38
# humK 48 151.0 189 0.2
# humK 49 183.0 211 0.13
# Mean of AER System  humK : 0.6652
# humV 0 45.0 75 0.4
# humV 1 129.0 284 0.54
# humV 2 27.0 367 0.92
# humV 3 73.0 106 0.31
# humV 4 204.0 578 0.64
# humV 5 97.0 619 0.84
# humV 6 203.0 280 0.27
# humV 7 89.0 108 0.17
# humV 8 33.0 339 0.9
# humV 9 6.0 45 0.86
# humV 10 62.0 154 0.59
# humV 11 45.0 167 0.73
# humV 12 22.0 166 0.86
# humV 13 59.0 171 0.65
# humV 14 30.0 285 0.89
# humV 15 65.0 151 0.56
# humV 16 1.0 364 0.99
# humV 17 124.0 148 0.16
# humV 18 19.0 33 0.42
# humV 19 16.0 18 0.11
# humV 20 146.0 190 0.23
# humV 21 1.0 61 0.98
# humV 22 68.0 135 0.49
# humV 23 2.0 275 0.99
# humV 24 4.0 252 0.98
# humV 25 35.0 168 0.79
# humV 26 36.0 75 0.52
# humV 27 63.0 74 0.14
# humV 28 164.0 176 0.06
# humV 29 47.0 211 0.77
# humV 30 4.0 29 0.86
# humV 31 99.0 360 0.72
# humV 32 89.0 453 0.8
# humV 33 9.0 316 0.97
# humV 34 167.0 581 0.71
# humV 35 111.0 139 0.2
# humV 36 17.0 90 0.81
# humV 37 21.0 86 0.75
# humV 38 13.0 113 0.88
# humV 39 92.0 166 0.44
# humV 40 1.0 22 0.95
# humV 41 4.0 44 0.9
# humV 42 31.0 105 0.7
# humV 43 25.0 174 0.85
# humV 44 11.0 164 0.93
# humV 45 38.0 582 0.93
# humV 46 24.0 205 0.88
# humV 47 220.0 363 0.39
# humV 48 143.0 189 0.24
# humV 49 288.0 211 0.36
# Mean of AER System  humV : 0.6406
# ok9u 0 46.0 75 0.38
# ok9u 1 136.0 284 0.52
# ok9u 2 94.0 367 0.74
# ok9u 3 71.0 106 0.33
# ok9u 4 221.0 578 0.61
# ok9u 5 72.0 619 0.88
# ok9u 6 157.0 280 0.43
# ok9u 7 65.0 108 0.39
# ok9u 8 22.0 339 0.93
# ok9u 9 8.0 45 0.82
# ok9u 10 67.0 154 0.56
# ok9u 11 44.0 167 0.73
# ok9u 12 13.0 166 0.92
# ok9u 13 98.0 171 0.42
# ok9u 14 38.0 285 0.86
# ok9u 15 227.0 151 0.5
# ok9u 16 0.0 364 1.0
# ok9u 17 137.0 148 0.07
# ok9u 18 27.0 33 0.18
# ok9u 19 16.0 18 0.11
# ok9u 20 104.0 190 0.45
# ok9u 21 5.0 61 0.91
# ok9u 22 71.0 135 0.47
# ok9u 23 2.0 275 0.99
# ok9u 24 15.0 252 0.94
# ok9u 25 51.0 168 0.69
# ok9u 26 37.0 75 0.5
# ok9u 27 62.0 74 0.16
# ok9u 28 116.0 176 0.34
# ok9u 29 25.0 211 0.88
# ok9u 30 6.0 29 0.79
# ok9u 31 199.0 360 0.44
# ok9u 32 62.0 453 0.86
# ok9u 33 11.0 316 0.96
# ok9u 34 319.0 581 0.45
# ok9u 35 56.0 139 0.59
# ok9u 36 9.0 90 0.9
# ok9u 37 24.0 86 0.72
# ok9u 38 21.0 113 0.81
# ok9u 39 123.0 166 0.25
# ok9u 40 4.0 22 0.81
# ok9u 41 5.0 44 0.88
# ok9u 42 34.0 105 0.67
# ok9u 43 22.0 174 0.87
# ok9u 44 22.0 164 0.86
# ok9u 45 103.0 582 0.82
# ok9u 46 20.0 205 0.9
# ok9u 47 149.0 363 0.58
# ok9u 48 161.0 189 0.14
# ok9u 49 178.0 211 0.15
# Mean of AER System  ok9u : 0.6232

# %%
f = open('/Users/ynh3/Documents/estR/traces/q3docs35/trace-0','rb')
f_output = open('/Users/ynh3/Documents/estR/estimates/est-0', 'w')

next(f)
#next(f)
count = 51
AER_arr=[]
n=3
lines=[]
line = '# Trace for numq = 2 x = 1 y = 50 trial 0\n'
lines.append(line)

#print header
#print "system, topic num, estR, relevant_judged, AER(estR, rel_judged[count]))"

for row in f:
    #initialization
    prev_marked=[]
    num_captured=[]
    marked_caught=[]

    #reading from file
    line = row.strip() 
    system = line.partition(' ')[0]
    line = line.partition(' ')[2]
    total_rel_first_round = line.split(' ')[5]
    new_rel_first_round = line.split(' ')[6]
    prev_marked.append(0)
    num_captured.append(total_rel_first_round)
    marked_caught.append(0)
    
    #print total_rel_first_round, new_rel_first_round
    row = next(f)
    line = row.strip()    
    line = line.partition(' ')[2]
    total_rel_second_round = line.split(' ')[5]
    new_rel_second_round = line.split(' ')[6]
    rel_overlap_second = float(total_rel_second_round) - float(new_rel_second_round)
    prev_marked.append(total_rel_first_round)
    num_captured.append(total_rel_second_round)
    marked_caught.append(rel_overlap_second)
    
    #next row
    row = next(f)
    line = row.strip()    
    line = line.partition(' ')[2]
    total_rel_third_round = line.split(' ')[5]
    new_rel_third_round = line.split(' ')[6]
    rel_overlap_third = float(total_rel_third_round) - float(new_rel_third_round)
    marked_before_third = float(total_rel_first_round) + float(total_rel_second_round) - float(rel_overlap_second)
    prev_marked.append(marked_before_third)
    num_captured.append(total_rel_third_round)
    marked_caught.append(rel_overlap_third)
    
    ##print prev_marked
    ##print num_captured
    ##print marked_caught
    N = capture_recapture_schnabel_index_iteration(n, prev_marked, num_captured, marked_caught)
    ##N = capture_recapture_chapman(3, total_rel_first_round, total_rel_second_round, rel_overlap_second,)
    index = count - 51
    AER_arr.append(AER(N,float(rel_judged[index]))) 
    #print system, index, N, rel_judged[index], AER(N,float(rel_judged[index]))
    #print system, count, N
    lines.append('{} {} {}\n'.format(system, count, N))
    ##AER(N,float(rel_judged[count]))
    count = count +1
    if count > 100: 
        #print "Mean of AER System ", system, ":", numpy.mean(AER_arr)
        count = 51
        AER_arr =[]
f_output.writelines(lines)
f_output.close()

# %%
for i in range(0,100):
    
    f = open('/Users/ynh3/Documents/estR/traces/q3docs50/trace-'+ str(i),'rb')
    f_output = open('/Users/ynh3/Documents/estR/estimates/cap_recap_q3docs50/est-'+ str(i), 'w')

    next(f)
    #next(f)
    count = 51
    AER_arr=[]
    n=3
    lines=[]
    line = '# Trace for numq = 3 x = 1 y = 50 trial ' + str(i) + '\n'
    lines.append(line)

    #print header
    #print "system, topic num, estR, relevant_judged, AER(estR, rel_judged[count]))"

    for row in f:
        #initialization
        prev_marked=[]
        num_captured=[]
        marked_caught=[]

        #reading from file
        line = row.strip() 
        system = line.partition(' ')[0]
        line = line.partition(' ')[2]
        total_rel_first_round = line.split(' ')[5]
        new_rel_first_round = line.split(' ')[6]
        prev_marked.append(0)
        num_captured.append(total_rel_first_round)
        marked_caught.append(0)

        #print total_rel_first_round, new_rel_first_round
        row = next(f)
        line = row.strip()    
        line = line.partition(' ')[2]
        total_rel_second_round = line.split(' ')[5]
        new_rel_second_round = line.split(' ')[6]
        rel_overlap_second = float(total_rel_second_round) - float(new_rel_second_round)
        prev_marked.append(total_rel_first_round)
        num_captured.append(total_rel_second_round)
        marked_caught.append(rel_overlap_second)

        #next row
        row = next(f)
        line = row.strip()    
        line = line.partition(' ')[2]
        total_rel_third_round = line.split(' ')[5]
        new_rel_third_round = line.split(' ')[6]
        rel_overlap_third = float(total_rel_third_round) - float(new_rel_third_round)
        marked_before_third = float(total_rel_first_round) + float(total_rel_second_round) - float(rel_overlap_second)
        prev_marked.append(marked_before_third)
        num_captured.append(total_rel_third_round)
        marked_caught.append(rel_overlap_third)

        ##print prev_marked
        ##print num_captured
        ##print marked_caught
        N = capture_recapture_schnabel_index_iteration(n, prev_marked, num_captured, marked_caught)
        ##N = capture_recapture_chapman(3, total_rel_first_round, total_rel_second_round, rel_overlap_second,)
        index = count - 51
        AER_arr.append(AER(N,float(rel_judged[index]))) 
        #print system, index, N, rel_judged[index], AER(N,float(rel_judged[index]))
        #print system, count, N
        lines.append('{} {} {}\n'.format(system, count, N))
        ##AER(N,float(rel_judged[count]))
        count = count +1
        if count > 100: 
            #print "Mean of AER System ", system, ":", numpy.mean(AER_arr)
            count = 51
            AER_arr =[]
    f_output.writelines(lines)
    f_output.close()

# %%
for i in range(0,100):
    
    f = open('/Users/ynh3/Documents/estR/traces/q3docs50/trace-'+ str(i),'rb')
    f_output = open('/Users/ynh3/Documents/estR/estimates/cap_recap_q3docs50/est-'+ str(i), 'w')

    next(f)
    #next(f)
    count = 51
    AER_arr=[]
    n=3
    lines=[]
    line = '# Trace for numq = 3 x = 1 y = 50 trial ' + str(i) + '\n'
    lines.append(line)

    #print header
    #print "system, topic num, estR, relevant_judged, AER(estR, rel_judged[count]))"

    for row in f:
        #initialization
        prev_marked=[]
        num_captured=[]
        marked_caught=[]

        #reading from file
        line = row.strip() 
        system = line.partition(' ')[0]
        line = line.partition(' ')[2]
        total_rel_first_round = line.split(' ')[5]
        new_rel_first_round = line.split(' ')[6]
        prev_marked.append(0)
        num_captured.append(total_rel_first_round)
        marked_caught.append(0)

        #print total_rel_first_round, new_rel_first_round
        row = next(f)
        line = row.strip()    
        line = line.partition(' ')[2]
        total_rel_second_round = line.split(' ')[5]
        new_rel_second_round = line.split(' ')[6]
        rel_overlap_second = float(total_rel_second_round) - float(new_rel_second_round)
        prev_marked.append(total_rel_first_round)
        num_captured.append(total_rel_second_round)
        marked_caught.append(rel_overlap_second)

        #next row
        row = next(f)
        line = row.strip()    
        line = line.partition(' ')[2]
        total_rel_third_round = line.split(' ')[5]
        new_rel_third_round = line.split(' ')[6]
        rel_overlap_third = float(total_rel_third_round) - float(new_rel_third_round)
        marked_before_third = float(total_rel_first_round) + float(total_rel_second_round) - float(rel_overlap_second)
        prev_marked.append(marked_before_third)
        num_captured.append(total_rel_third_round)
        marked_caught.append(rel_overlap_third)

        ##print prev_marked
        ##print num_captured
        ##print marked_caught
        N = capture_recapture_schnabel_index_iteration(n, prev_marked, num_captured, marked_caught)
        ##N = capture_recapture_chapman(3, total_rel_first_round, total_rel_second_round, rel_overlap_second,)
        index = count - 51
        AER_arr.append(AER(N,float(rel_judged[index]))) 
        #print system, index, N, rel_judged[index], AER(N,float(rel_judged[index]))
        #print system, count, N
        lines.append('{} {} {}\n'.format(system, count, N))
        ##AER(N,float(rel_judged[count]))
        count = count +1
        if count > 100: 
            #print "Mean of AER System ", system, ":", numpy.mean(AER_arr)
            count = 51
            AER_arr =[]
    f_output.writelines(lines)
    f_output.close()

# %%
prev_marked=[0,100,170]
num_captured=[100,85,105]
marked_caught=[0,15,25]

# %%
#### TRY & ERROR TEST BEGINS

# %%
import numpy
>>> a = [1.3, 2.4, 4.5]
>>> numpy.mean(a)
truncate(2.34567,2)
# Out:
# '2.34'

# %%
data = list(csv.reader(open('/Users/ynh3/Documents/estR/trace.2q50docs', 'rb'), delimiter='\t'))

# %%
data[3]
# Out:
# ['IN7a 51 1  68 39 38 12 6']

# %%
name = "word1 word2 word3"
print name.split(" ")[0]
# Out:
# word1

# %%
name2 = "51:      894 judged;     75 rel"
print name2.partition(' ')[2]
# Out:
#      894 judged;     75 rel

# %%
name3 = "51:      894 judged;     75 rel"
name3 = name3.strip()
print name3.split(' ')[12]
# Out:
# 75
